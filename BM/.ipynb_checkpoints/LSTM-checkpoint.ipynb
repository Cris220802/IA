# %% [markdown]
# ## Importacion de datos

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in d:\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in d:\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in d:\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in d:\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.reset_option("display.max_rows")
pd.set_option('display.max_columns', None)
filename = 'au_recuperacion.csv'

df = pd.read_csv(filename)
df
# Out:
#      toneladas  au_concentrado_pb  ag_concentrado_pb  pb_concentrado_pb  \
# 0      2068.40          37.388892       10725.032307          38.863268
# 1      1857.10          37.887393        9050.180473          38.046329
# 2      1864.90          35.407624        8540.127675          47.838230
# 3      2079.70          34.192846        8589.673605          38.903346
# 4      1988.90          40.624590        9609.113956          39.120814
# ..         ...                ...                ...                ...
# 824    2017.94          15.269189        8647.058484          39.966413
# 825    2042.20          15.368160        7117.069787          38.254328
# 826    2042.20          15.352869        6147.698548          37.666006
# 827    2138.67          16.363678        7442.734495          35.890986
# 828    2091.27          21.846085        8564.886541          40.132117
#
#      ag_colas_pb  ag_concentrado_zn  ag_colas_zn  dia  dias_desde_inicio  \
# 0      54.280130          33.320482   639.625521    3                  1
# 1      67.569943          33.900568   639.566745    4                  2
# 2      68.330141          41.502844   639.901051    4                  2
# 3      88.709979          40.722534   639.850368    5                  3
# 4      65.509836          39.382763   640.025235    5                  3
# ..           ...                ...          ...  ...                ...
# 824    76.565783          55.893263   416.526665   29                452
# 825    81.475597          61.373800   470.219341   30                453
# 826   108.346710          82.411300   473.131417   30                453
# 827    94.819412          64.420435   290.332965   31                454
# 828    87.578244          58.335344   324.088903   31                454
#
#      au_recuperacion  pb_recuperacion  fe_recuperacion  ag_contenido  \
# 0          67.360786        89.615372       -13.524190    542.666720
# 1          70.736983        89.931045       -13.191936    448.168735
# 2          65.392053        86.592091        -5.457701    365.012561
# 3          74.071448        84.021609        -5.927354    624.367928
# 4          66.090970        85.750166        -7.657547    418.297519
# ..               ...              ...              ...           ...
# 824        75.920493        78.107871        18.237782    688.815203
# 825        83.961391        87.352263        23.859670    822.321519
# 826        82.811343        86.510181        40.707147    703.694143
# 827        87.899513        84.172378        35.447403   1056.426549
# 828        85.596907        83.033671        20.346179    854.540674
#
#      pb_contenido  zn_contenido  ag_concentrado_pb_ley  pb_concentrado_pb_ley  \
# 0       19.144081     29.539510           10725.032307              38.863268
# 1       17.239580     32.335838            9050.180473              38.046329
# 2       18.173777     34.227878            8540.127675              47.838230
# 3       24.311314     46.029288            8589.673605              38.903346
# 4       15.496098     36.991621            9609.113956              39.120814
# ..            ...           ...                    ...                    ...
# 824     28.242087     52.123218            8647.058484              39.966413
# 825     38.823788     52.241656            7117.069787              38.254328
# 826     33.627777     47.229481            6147.698548              37.666006
# 827     44.464655     51.560804            7442.734495              35.890986
# 828     35.163209     60.794343            8564.886541              40.132117
#
#      ag_concentrado_zn_ley  zn_concentrado_zn_ley  ag_concentrado_fe_ley  \
# 0               750.772639              50.077870             639.625521
# 1               852.150337              43.373812             639.566745
# 2               751.236576              49.565713             639.901051
# 3               891.820427              40.470202             639.850368
# 4               693.968030              47.544751             640.025235
# ..                     ...                    ...                    ...
# 824             459.733611              52.290176             416.526665
# 825             454.182948              52.602052             470.219341
# 826             584.498475              46.818174             473.131417
# 827             654.273788              49.656571             290.332965
# 828             531.857895              49.131637             324.088903
#
#      toneladas_lag2  toneladas_lag3  ag_cabeza_lag1  ag_cabeza_lag3  \
# 0           1736.90         2042.20      386.740000      395.810002
# 1           1955.00         1736.90      308.410002      350.599999
# 2           2068.40         1955.00      286.739996      386.740000
# 3           1857.10         2068.40      240.909999      308.410002
# 4           1864.90         1857.10      344.149998      286.739996
# ..              ...             ...             ...             ...
# 824         2042.20         1890.99      423.976679      348.580832
# 825         2008.30         2042.20      376.688699      390.998043
# 826         2017.94         2008.30      431.114568      423.976679
# 827         2042.20         2017.94      372.369027      376.688699
# 828         2042.20         2042.20      520.466722      431.114568
#
#      au_concentrado_pb_lag2  ag_concentrado_pb_lag1  ag_concentrado_pb_lag2  \
# 0                 31.055118            11565.332135            13517.780309
# 1                 29.936189            10725.032307            11565.332135
# 2                 37.388892             9050.180473            10725.032307
# 3                 37.887393             8540.127675             9050.180473
# 4                 35.407624             8589.673605             8540.127675
# ..                      ...                     ...                     ...
# 824               26.196888             7954.520229             9107.935314
# 825               16.338197             8647.058484             7954.520229
# 826               15.269189             7117.069787             8647.058484
# 827               15.368160             6147.698548             7117.069787
# 828               15.352869             7442.734495             6147.698548
#
#      ag_concentrado_pb_lag3  ag_colas_pb_lag1  ag_colas_pb_lag3  \
# 0              14143.800961         71.960020         68.253954
# 1              13517.780309         54.280130         72.489921
# 2              11565.332135         67.569943         71.960020
# 3              10725.032307         68.330141         54.280130
# 4               9050.180473         88.709979         67.569943
# ..                      ...               ...               ...
# 824             8889.332031         79.897686         82.556097
# 825             9107.935314         76.565783         80.623961
# 826             7954.520229         81.475597         79.897686
# 827             8647.058484        108.346710         76.565783
# 828             7117.069787         94.819412         81.475597
#
#      ag_colas_zn_lag1  ag_colas_zn_lag3  fe_colas_zn_lag2  \
# 0          639.476068        640.014986         34.827484
# 1          639.625521        639.049666         34.757763
# 2          639.566745        639.476068         34.573644
# 3          639.901051        639.625521         34.677839
# 4          639.850368        639.566745         34.714567
# ..                ...               ...               ...
# 824        485.299795        470.504585         33.635510
# 825        416.526665        474.468710         33.231910
# 826        470.219341        485.299795         33.502127
# 827        473.131417        416.526665         32.986070
# 828        290.332965        470.219341         29.799700
#
#      ag_concentrado_fe_lag1  ag_concentrado_fe_lag2  ag_colas_fe_lag1  \
# 0                 47.458215               47.460866             47.46
# 1                 47.459247               47.458215             47.46
# 2                 47.459353               47.459247             47.46
# 3                 47.456787               47.459353             47.46
# 4                 47.457392               47.456787             47.46
# ..                      ...                     ...               ...
# 824               45.860843               35.130944             45.86
# 825               40.273450               45.860843             40.27
# 826               33.689054               40.273450             33.69
# 827               34.411000               33.689054             34.41
# 828               33.694754               34.411000             33.69
#
#      ag_colas_fe_lag2  au_recuperacion_lag2  au_recuperacion_lag3  \
# 0               47.46             63.721450             62.742370
# 1               47.46             68.335607             63.721450
# 2               47.46             67.360786             68.335607
# 3               47.46             70.736983             67.360786
# 4               47.46             65.392053             70.736983
# ..                ...                   ...                   ...
# 824             35.13             79.153353             82.542757
# 825             45.86             79.307934             79.153353
# 826             40.27             75.920493             79.307934
# 827             33.69             83.961391             75.920493
# 828             34.41             82.811343             83.961391
#
#      zn_recuperacion_lag1  zn_recuperacion_lag2  zn_recuperacion_lag3  \
# 0               77.982038             83.971925             19.752700
# 1               79.272610             77.982038             83.971925
# 2               81.392765             79.272610             77.982038
# 3               84.130660             81.392765             79.272610
# 4               83.817214             84.130660             81.392765
# ..                    ...                   ...                   ...
# 824             75.903516             65.578568             67.733075
# 825             73.994397             75.903516             65.578568
# 826             65.608074             73.994397             75.903516
# 827             71.732642             65.608074             73.994397
# 828             65.231212             71.732642             65.608074
#
#      ag_contenido_lag1  ag_contenido_lag2  zn_contenido_lag2  \
# 0           668.142257         530.177258          28.326183
# 1           542.666720         668.142257          28.996267
# 2           448.168735         542.666720          29.539510
# 3           365.012561         448.168735          32.335838
# 4           624.367928         365.012561          34.227878
# ..                 ...                ...                ...
# 824         770.643550         734.950332          32.898532
# 825         688.815203         770.643550          52.392148
# 826         822.321519         688.815203          52.123218
# 827         703.694143         822.321519          52.241656
# 828        1056.426549         703.694143          47.229481
#
#      zn_contenido_lag3  ag_concentrado_pb_ley_lag1  \
# 0             2.647098                11565.332135
# 1            28.326183                10725.032307
# 2            28.996267                 9050.180473
# 3            29.539510                 8540.127675
# 4            32.335838                 8589.673605
# ..                 ...                         ...
# 824          36.396386                 7954.520229
# 825          32.898532                 8647.058484
# 826          52.392148                 7117.069787
# 827          52.123218                 6147.698548
# 828          52.241656                 7442.734495
#
#      ag_concentrado_pb_ley_lag2  ag_concentrado_pb_ley_lag3  \
# 0                  13517.780309                14143.800961
# 1                  11565.332135                13517.780309
# 2                  10725.032307                11565.332135
# 3                   9050.180473                10725.032307
# 4                   8540.127675                 9050.180473
# ..                          ...                         ...
# 824                 9107.935314                 8889.332031
# 825                 7954.520229                 9107.935314
# 826                 8647.058484                 7954.520229
# 827                 7117.069787                 8647.058484
# 828                 6147.698548                 7117.069787
#
#      ag_concentrado_zn_ley_lag1  ag_concentrado_zn_ley_lag2  \
# 0                    943.354408                  919.398482
# 1                    750.772639                  943.354408
# 2                    852.150337                  750.772639
# 3                    751.236576                  852.150337
# 4                    891.820427                  751.236576
# ..                          ...                         ...
# 824                  445.482420                  749.585276
# 825                  459.733611                  445.482420
# 826                  454.182948                  459.733611
# 827                  584.498475                  454.182948
# 828                  654.273788                  584.498475
#
#      ag_concentrado_zn_ley_lag3  zn_concentrado_zn_ley_lag1  \
# 0                   1189.957338                   49.413741
# 1                    919.398482                   50.077870
# 2                    943.354408                   43.373812
# 3                    750.772639                   49.565713
# 4                    852.150337                   40.470202
# ..                          ...                         ...
# 824                  809.432599                   50.981765
# 825                  749.585276                   52.290176
# 826                  445.482420                   52.602052
# 827                  459.733611                   46.818174
# 828                  454.182948                   49.656571
#
#      ag_concentrado_fe_ley_lag1  ag_concentrado_fe_ley_lag3  \
# 0                    639.476068                  640.014986
# 1                    639.625521                  639.049666
# 2                    639.566745                  639.476068
# 3                    639.901051                  639.625521
# 4                    639.850368                  639.566745
# ..                          ...                         ...
# 824                  485.299795                  470.504585
# 825                  416.526665                  474.468710
# 826                  470.219341                  485.299795
# 827                  473.131417                  416.526665
# 828                  290.332965                  470.219341
#
#      fe_concentrado_fe_ley_lag2  zn_recuperacion
# 0                     34.827484        79.272610
# 1                     34.757763        81.392765
# 2                     34.573644        84.130660
# 3                     34.677839        83.817214
# 4                     34.714567        84.023755
# ..                          ...              ...
# 824                   33.635510        73.994397
# 825                   33.231910        65.608074
# 826                   33.502127        71.732642
# 827                   32.986070        65.231212
# 828                   29.799700        78.026846
#
# [829 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   toneladas                   829 non-null    float64
#  1   au_concentrado_pb           829 non-null    float64
#  2   ag_concentrado_pb           829 non-null    float64
#  3   pb_concentrado_pb           829 non-null    float64
#  4   ag_colas_pb                 829 non-null    float64
#  5   ag_concentrado_zn           829 non-null    float64
#  6   ag_colas_zn                 829 non-null    float64
#  7   dia                         829 non-null    int64
#  8   dias_desde_inicio           829 non-null    int64
#  9   au_recuperacion             829 non-null    float64
#  10  pb_recuperacion             829 non-null    float64
#  11  fe_recuperacion             829 non-null    float64
#  12  ag_contenido                829 non-null    float64
#  13  pb_contenido                829 non-null    float64
#  14  zn_contenido                829 non-null    float64
#  15  ag_concentrado_pb_ley       829 non-null    float64
#  16  pb_concentrado_pb_ley       829 non-null    float64
#  17  ag_concentrado_zn_ley       829 non-null    float64
#  18  zn_concentrado_zn_ley       829 non-null    float64
#  19  ag_concentrado_fe_ley       829 non-null    float64
#  20  toneladas_lag2              829 non-null    float64
#  21  toneladas_lag3              829 non-null    float64
#  22  ag_cabeza_lag1              829 non-null    float64
#  23  ag_cabeza_lag3              829 non-null    float64
#  24  au_concentrado_pb_lag2      829 non-null    float64
#  25  ag_concentrado_pb_lag1      829 non-null    float64
#  26  ag_concentrado_pb_lag2      829 non-null    float64
#  27  ag_concentrado_pb_lag3      829 non-null    float64
#  28  ag_colas_pb_lag1            829 non-null    float64
#  29  ag_colas_pb_lag3            829 non-null    float64
#  30  ag_colas_zn_lag1            829 non-null    float64
#  31  ag_colas_zn_lag3            829 non-null    float64
#  32  fe_colas_zn_lag2            829 non-null    float64
#  33  ag_concentrado_fe_lag1      829 non-null    float64
#  34  ag_concentrado_fe_lag2      829 non-null    float64
#  35  ag_colas_fe_lag1            829 non-null    float64
#  36  ag_colas_fe_lag2            829 non-null    float64
#  37  au_recuperacion_lag2        829 non-null    float64
#  38  au_recuperacion_lag3        829 non-null    float64
#  39  zn_recuperacion_lag1        829 non-null    float64
#  40  zn_recuperacion_lag2        829 non-null    float64
#  41  zn_recuperacion_lag3        829 non-null    float64
#  42  ag_contenido_lag1           829 non-null    float64
#  43  ag_contenido_lag2           829 non-null    float64
#  44  zn_contenido_lag2           829 non-null    float64
#  45  zn_contenido_lag3           829 non-null    float64
#  46  ag_concentrado_pb_ley_lag1  829 non-null    float64
#  47  ag_concentrado_pb_ley_lag2  829 non-null    float64
#  48  ag_concentrado_pb_ley_lag3  829 non-null    float64
#  49  ag_concentrado_zn_ley_lag1  829 non-null    float64
#  50  ag_concentrado_zn_ley_lag2  829 non-null    float64
#  51  ag_concentrado_zn_ley_lag3  829 non-null    float64
#  52  zn_concentrado_zn_ley_lag1  829 non-null    float64
#  53  ag_concentrado_fe_ley_lag1  829 non-null    float64
#  54  ag_concentrado_fe_ley_lag3  829 non-null    float64
#  55  fe_concentrado_fe_ley_lag2  829 non-null    float64
#  56  zn_recuperacion             829 non-null    float64
# dtypes: float64(55), int64(2)
# memory usage: 369.3 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Especificamos la columna que queremos visualizar
columna = "zn_recuperacion"  # cambia esto por el nombre real de la columna

# Graficamos la columna
df[columna].plot(figsize=(12, 6), title=f"Gráfico de {columna}")
plt.xlabel("Índice")
plt.ylabel(columna)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def train_val_test_split(df, tr_size=0.8, vl_size=0.1, ts_size=0.1):
    #Definimos el numero de datos en cada subserie
    N = df.shape[0]
    Ntrain = int(tr_size*N)
    Nval = int(vl_size*N)
    Ntst = N - Ntrain - Nval

    # Realizar particion
    train = df[0:Ntrain]
    val = df[Ntrain:Ntrain+Nval]
    test = df[Ntrain+Nval:]

    return train, val, test

# %%
tr, vl, ts = train_val_test_split(df)
print(f"tam set de entrenamiento: {tr.shape}")
print(f"tam set de validacion: {vl.shape}")
print(f"tam set de test: {ts.shape}")
# Out:
# tam set de entrenamiento: (663, 57)
# tam set de validacion: (82, 57)
# tam set de test: (84, 57)

# %%
import numpy as np

def crear_dataset_supervisado(array, input_length, output_length):
    '''Permite crear un dataset con las entradas (X) y salidas (Y)
    requeridas por la Red LSTM.

    Parámetros:
    - array: arreglo numpy de tamaño N x features (N: cantidad de datos,
      f: cantidad de features)
    - input_length: instantes de tiempo consecutivos de la(s) serie(s) de tiempo
      usados para alimentar el modelo
    - output_length: instantes de tiempo a pronosticar (salida del modelo)
    '''

    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape)==1: # Si tenemos sólo una serie (univariado)
        fils, cols = array.shape[0], 1
        array = array.reshape(fils,cols)
    else: # Multivariado 
        fils, cols = array.shape

    # Generar los arreglos
    for i in range(fils-input_length-output_length):
        X.append(array[i:i+INPUT_LENGTH,0:cols])
        Y.append(array[i+input_length:i+input_length+output_length,-1].reshape(output_length,1))
    
    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
# Crear los datasets de entrenamiento, prueba y validación y verificar sus tamaños
INPUT_LENGTH = 1   # Hiperparámetro
OUTPUT_LENGTH = 2    # Modelo multi-step

x_tr, y_tr = crear_dataset_supervisado(tr.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_vl, y_vl = crear_dataset_supervisado(vl.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_ts, y_ts = crear_dataset_supervisado(ts.values, INPUT_LENGTH, OUTPUT_LENGTH)

# Imprimir información en pantalla
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (660, 1, 57), y_tr: (660, 2, 1)
# Set de validación - x_vl: (79, 1, 57), y_vl: (79, 2, 1)
# Set de prueba - x_ts: (81, 1, 57), y_ts: (81, 2, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

def escalar_dataset(data_input, col_ref):
    '''Escala el dataset en el rango de -1 a 1.

    Entradas:
    - data_input: diccionario con los dataset de entrada y salida del modelo
    (data_input = {'x_tr':x_tr, 'y_tr':y_tr, 'x_vl':x_vl, 'y_vl':y_vl,
                    'y_ts':y_ts})
    - col_ref: parámetro adicional para especificar la columna que contiene
      la variable a predecir

    
    Retorna:
    - data_scaled: diccionario con los datasets de entrada y salida escalados
      (tiene la misma estructura del diccionario de entrada)
    - scaler: el escalador usado (requerido para las predicciones)
    '''

    # *** Implementación adicional: determinar el índice de la columna
    # que contiene la variable a predecir
    col_ref = df.columns.get_loc(col_ref)

    # Número de instantes de tiempo de entrada y de covariables
    NSAMPLES = data_input['x_tr'].shape[1]
    NFEATS = data_input['x_tr'].shape[2]

    # Generar listado con "scalers" (1 por cada covariable de entrada)
    scalers = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)]

    # Arreglos que contendrán los datasets escalados
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)

    # Escalamiento: se usarán los min/max del set de entrenamiento para
    # escalar la totalidad de los datasets

    # Escalamiento Xs
    for i in range(NFEATS):
        x_tr_s[:,:,i] = scalers[i].fit_transform(x_tr[:,:,i])
        x_vl_s[:,:,i] = scalers[i].transform(x_vl[:,:,i])
        x_ts_s[:,:,i] = scalers[i].transform(x_ts[:,:,i])
    
    # Escalamiento Ys (teniendo en cuenta "col_ind")
    y_tr_s[:,:,0] = scalers[col_ref].fit_transform(y_tr[:,:,0])
    y_vl_s[:,:,0] = scalers[col_ref].transform(y_vl[:,:,0])
    y_ts_s[:,:,0] = scalers[col_ref].transform(y_ts[:,:,0])

    # Conformar diccionario de salida
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    return data_scaled, scalers[col_ref]

# %%
# Escalamiento del dataset con la función anterior

# Crear diccionario de entrada
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Y escalar (especificando la columna con la variable a predecir)
data_s, scaler = escalar_dataset(data_in, col_ref = 'zn_recuperacion' )

# Extraer subsets escalados
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

x_tr_s.shape
# Out:
# (660, 1, 57)

# %%
# Y generemos una gráfica tipo violín para ver la distribución
# de los valores en cada covariable (entrada) y en la variable a
# predecir (salida)

fig, ax = plt.subplots(figsize=(12,4))
for i in range(13):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

# Etiquetas eje horizontal
ax.set_xticks(list(range(13)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[444], line 13
#      11 # Etiquetas eje horizontal
#      12 ax.set_xticks(list(range(13)))
# ---> 13 ax.set_xticklabels(df.keys(), rotation=90)
#      14 ax.autoscale()
#
# File D:\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\matplotlib\axis.py:2071, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2067 elif isinstance(locator, mticker.FixedLocator):
#    2068     # Passing [] as a list of labels is often used as a way to
#    2069     # remove all tick labels, so only error for > 0 labels
#    2070     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2071         raise ValueError(
#    2072             "The number of FixedLocator locations"
#    2073             f" ({len(locator.locs)}), usually from a call to"
#    2074             " set_ticks, does not match"
#    2075             f" the number of labels ({len(labels)}).")
#    2076     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2077     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (13), usually from a call to set_ticks, does not match the number of labels (57).

# %%
# Y hagamos lo mismo con la variable de salida:
fig, ax = plt.subplots(figsize=(6,4))
ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())
ax.set_xticks([1])
ax.set_xticklabels(['y (salida)']);

# %% [markdown]
# ## Recomendaciones
# 1. Tomarlo por mineral
# 2. Entrenar solo para Recuperaciones y Leyes
# 3. Probar otros modelos que no sean de Deep Learning (por el tiempo y conocimiento)
# 4. Intentar Regresion Lineal y Logistica
# 5. Utilizar un Regresor Random Forest
# 6. Investigar el escalamiento por feature, investigar como hace el escalamiento el StandardScaler
# 7. Probar con los 0s en el ajuste
# 8. Quitar las columnas con valores faltantes y probar el ajuste
# 9. En vez de ser data augmentation el lag debe servir para el mantenimiento del modelo (lag de features)

# %% [markdown]
# ## Entrenamiento del Modelo

# %% [markdown]
# ## Opcion 1:

# %%
# Creación del modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop, Adam
import tensorflow as tf

# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

## Son demasiadas unidades REVISAR
# El modelo
N_UNITS = 32 # Tamaño del estado oculto (h) y de la celdad de memoria (c) (128)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 5 dias x 45 (features)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))

modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' pues queremos pronosticar (regresión)
# Pérdida: se usará el RMSE (root mean squared error) para el entrenamiento
# pues permite tener errores en las mismas unidades
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compilación
optimizador = RMSprop(learning_rate=5e-4) # 5e-5
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
)

# Entrenamiento (aproximadamente 1 min usando GPU)
EPOCHS = 200 # Hiperparámetro
BATCH_SIZE = 128 # Hiperparámetro
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# Epoch 1/200
# D:\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 - 2s - 468ms/step - loss: 0.4300 - val_loss: 0.3158
# Epoch 2/200
# 4/4 - 0s - 24ms/step - loss: 0.3789 - val_loss: 0.2885
# Epoch 3/200
# 4/4 - 0s - 25ms/step - loss: 0.3484 - val_loss: 0.2689
# Epoch 4/200
# 4/4 - 0s - 26ms/step - loss: 0.3265 - val_loss: 0.2538
# Epoch 5/200
# 4/4 - 0s - 25ms/step - loss: 0.3106 - val_loss: 0.2419
# Epoch 6/200
# 4/4 - 0s - 24ms/step - loss: 0.2994 - val_loss: 0.2325
# Epoch 7/200
# 4/4 - 0s - 25ms/step - loss: 0.2917 - val_loss: 0.2252
# Epoch 8/200
# 4/4 - 0s - 25ms/step - loss: 0.2864 - val_loss: 0.2194
# Epoch 9/200
# 4/4 - 0s - 24ms/step - loss: 0.2826 - val_loss: 0.2150
# Epoch 10/200
# 4/4 - 0s - 24ms/step - loss: 0.2797 - val_loss: 0.2114
# Epoch 11/200
# 4/4 - 0s - 25ms/step - loss: 0.2773 - val_loss: 0.2086
# Epoch 12/200
# 4/4 - 0s - 26ms/step - loss: 0.2754 - val_loss: 0.2061
# Epoch 13/200
# 4/4 - 0s - 24ms/step - loss: 0.2736 - val_loss: 0.2039
# Epoch 14/200
# 4/4 - 0s - 25ms/step - loss: 0.2720 - val_loss: 0.2019
# Epoch 15/200
# 4/4 - 0s - 25ms/step - loss: 0.2706 - val_loss: 0.1999
# Epoch 16/200
# 4/4 - 0s - 26ms/step - loss: 0.2692 - val_loss: 0.1980
# Epoch 17/200
# 4/4 - 0s - 25ms/step - loss: 0.2679 - val_loss: 0.1962
# Epoch 18/200
# 4/4 - 0s - 23ms/step - loss: 0.2667 - val_loss: 0.1945
# Epoch 19/200
# 4/4 - 0s - 26ms/step - loss: 0.2656 - val_loss: 0.1928
# Epoch 20/200
# 4/4 - 0s - 25ms/step - loss: 0.2646 - val_loss: 0.1912
# Epoch 21/200
# 4/4 - 0s - 24ms/step - loss: 0.2636 - val_loss: 0.1896
# Epoch 22/200
# 4/4 - 0s - 24ms/step - loss: 0.2627 - val_loss: 0.1882
# Epoch 23/200
# 4/4 - 0s - 24ms/step - loss: 0.2618 - val_loss: 0.1868
# Epoch 24/200
# 4/4 - 0s - 25ms/step - loss: 0.2610 - val_loss: 0.1855
# Epoch 25/200
# 4/4 - 0s - 26ms/step - loss: 0.2602 - val_loss: 0.1842
# Epoch 26/200
# 4/4 - 0s - 25ms/step - loss: 0.2595 - val_loss: 0.1831
# Epoch 27/200
# 4/4 - 0s - 25ms/step - loss: 0.2588 - val_loss: 0.1820
# Epoch 28/200
# 4/4 - 0s - 24ms/step - loss: 0.2582 - val_loss: 0.1810
# Epoch 29/200
# 4/4 - 0s - 25ms/step - loss: 0.2576 - val_loss: 0.1800
# Epoch 30/200
# 4/4 - 0s - 24ms/step - loss: 0.2570 - val_loss: 0.1791
# Epoch 31/200
# 4/4 - 0s - 26ms/step - loss: 0.2564 - val_loss: 0.1783
# Epoch 32/200
# 4/4 - 0s - 26ms/step - loss: 0.2559 - val_loss: 0.1775
# Epoch 33/200
# 4/4 - 0s - 26ms/step - loss: 0.2554 - val_loss: 0.1768
# Epoch 34/200
# 4/4 - 0s - 30ms/step - loss: 0.2549 - val_loss: 0.1761
# Epoch 35/200
# 4/4 - 0s - 37ms/step - loss: 0.2545 - val_loss: 0.1755
# Epoch 36/200
# 4/4 - 0s - 28ms/step - loss: 0.2540 - val_loss: 0.1749
# Epoch 37/200
# 4/4 - 0s - 28ms/step - loss: 0.2536 - val_loss: 0.1744
# Epoch 38/200
# 4/4 - 0s - 29ms/step - loss: 0.2532 - val_loss: 0.1739
# Epoch 39/200
# 4/4 - 0s - 35ms/step - loss: 0.2528 - val_loss: 0.1734
# Epoch 40/200
# 4/4 - 0s - 29ms/step - loss: 0.2525 - val_loss: 0.1730
# Epoch 41/200
# 4/4 - 0s - 28ms/step - loss: 0.2521 - val_loss: 0.1726
# Epoch 42/200
# 4/4 - 0s - 28ms/step - loss: 0.2517 - val_loss: 0.1722
# Epoch 43/200
# 4/4 - 0s - 29ms/step - loss: 0.2514 - val_loss: 0.1719
# Epoch 44/200
# 4/4 - 0s - 33ms/step - loss: 0.2511 - val_loss: 0.1716
# Epoch 45/200
# 4/4 - 0s - 30ms/step - loss: 0.2508 - val_loss: 0.1713
# Epoch 46/200
# 4/4 - 0s - 27ms/step - loss: 0.2504 - val_loss: 0.1710
# Epoch 47/200
# 4/4 - 0s - 27ms/step - loss: 0.2501 - val_loss: 0.1708
# Epoch 48/200
# 4/4 - 0s - 27ms/step - loss: 0.2498 - val_loss: 0.1706
# Epoch 49/200
# 4/4 - 0s - 27ms/step - loss: 0.2496 - val_loss: 0.1704
# Epoch 50/200
# 4/4 - 0s - 27ms/step - loss: 0.2493 - val_loss: 0.1702
# Epoch 51/200
# 4/4 - 0s - 28ms/step - loss: 0.2490 - val_loss: 0.1701
# Epoch 52/200
# 4/4 - 0s - 29ms/step - loss: 0.2487 - val_loss: 0.1700
# Epoch 53/200
# 4/4 - 0s - 26ms/step - loss: 0.2485 - val_loss: 0.1698
# Epoch 54/200
# 4/4 - 0s - 28ms/step - loss: 0.2482 - val_loss: 0.1697
# Epoch 55/200
# 4/4 - 0s - 33ms/step - loss: 0.2479 - val_loss: 0.1696
# Epoch 56/200
# 4/4 - 0s - 34ms/step - loss: 0.2477 - val_loss: 0.1696
# Epoch 57/200
# 4/4 - 0s - 29ms/step - loss: 0.2474 - val_loss: 0.1695
# Epoch 58/200
# 4/4 - 0s - 27ms/step - loss: 0.2472 - val_loss: 0.1695
# Epoch 59/200
# 4/4 - 0s - 26ms/step - loss: 0.2469 - val_loss: 0.1694
# Epoch 60/200
# 4/4 - 0s - 28ms/step - loss: 0.2467 - val_loss: 0.1694
# Epoch 61/200
# 4/4 - 0s - 27ms/step - loss: 0.2465 - val_loss: 0.1694
# Epoch 62/200
# 4/4 - 0s - 26ms/step - loss: 0.2462 - val_loss: 0.1694
# Epoch 63/200
# 4/4 - 0s - 27ms/step - loss: 0.2460 - val_loss: 0.1694
# Epoch 64/200
# 4/4 - 0s - 26ms/step - loss: 0.2458 - val_loss: 0.1695
# Epoch 65/200
# 4/4 - 0s - 26ms/step - loss: 0.2455 - val_loss: 0.1695
# Epoch 66/200
# 4/4 - 0s - 28ms/step - loss: 0.2453 - val_loss: 0.1696
# Epoch 67/200
# 4/4 - 0s - 29ms/step - loss: 0.2451 - val_loss: 0.1696
# Epoch 68/200
# 4/4 - 0s - 28ms/step - loss: 0.2449 - val_loss: 0.1697
# Epoch 69/200
# 4/4 - 0s - 29ms/step - loss: 0.2446 - val_loss: 0.1698
# Epoch 70/200
# 4/4 - 0s - 24ms/step - loss: 0.2444 - val_loss: 0.1699
# Epoch 71/200
# 4/4 - 0s - 25ms/step - loss: 0.2442 - val_loss: 0.1700
# Epoch 72/200
# 4/4 - 0s - 26ms/step - loss: 0.2440 - val_loss: 0.1701
# Epoch 73/200
# 4/4 - 0s - 24ms/step - loss: 0.2438 - val_loss: 0.1702
# Epoch 74/200
# 4/4 - 0s - 24ms/step - loss: 0.2436 - val_loss: 0.1703
# Epoch 75/200
# 4/4 - 0s - 25ms/step - loss: 0.2433 - val_loss: 0.1705
# Epoch 76/200
# 4/4 - 0s - 24ms/step - loss: 0.2431 - val_loss: 0.1706
# Epoch 77/200
# 4/4 - 0s - 25ms/step - loss: 0.2429 - val_loss: 0.1708
# Epoch 78/200
# 4/4 - 0s - 25ms/step - loss: 0.2427 - val_loss: 0.1710
# Epoch 79/200
# 4/4 - 0s - 25ms/step - loss: 0.2425 - val_loss: 0.1711
# Epoch 80/200
# 4/4 - 0s - 25ms/step - loss: 0.2423 - val_loss: 0.1713
# Epoch 81/200
# 4/4 - 0s - 25ms/step - loss: 0.2421 - val_loss: 0.1715
# Epoch 82/200
# 4/4 - 0s - 27ms/step - loss: 0.2419 - val_loss: 0.1717
# Epoch 83/200
# 4/4 - 0s - 27ms/step - loss: 0.2417 - val_loss: 0.1719
# Epoch 84/200
# 4/4 - 0s - 24ms/step - loss: 0.2415 - val_loss: 0.1721
# Epoch 85/200
# 4/4 - 0s - 26ms/step - loss: 0.2413 - val_loss: 0.1723
# Epoch 86/200
# 4/4 - 0s - 24ms/step - loss: 0.2411 - val_loss: 0.1725
# Epoch 87/200
# 4/4 - 0s - 26ms/step - loss: 0.2409 - val_loss: 0.1727
# Epoch 88/200
# 4/4 - 0s - 26ms/step - loss: 0.2407 - val_loss: 0.1729
# Epoch 89/200
# 4/4 - 0s - 28ms/step - loss: 0.2405 - val_loss: 0.1731
# Epoch 90/200
# 4/4 - 0s - 26ms/step - loss: 0.2403 - val_loss: 0.1734
# Epoch 91/200
# 4/4 - 0s - 25ms/step - loss: 0.2401 - val_loss: 0.1736
# Epoch 92/200
# 4/4 - 0s - 26ms/step - loss: 0.2399 - val_loss: 0.1738
# Epoch 93/200
# 4/4 - 0s - 28ms/step - loss: 0.2397 - val_loss: 0.1741
# Epoch 94/200
# 4/4 - 0s - 26ms/step - loss: 0.2395 - val_loss: 0.1743
# Epoch 95/200
# 4/4 - 0s - 25ms/step - loss: 0.2393 - val_loss: 0.1745
# Epoch 96/200
# 4/4 - 0s - 24ms/step - loss: 0.2391 - val_loss: 0.1748
# Epoch 97/200
# 4/4 - 0s - 29ms/step - loss: 0.2389 - val_loss: 0.1750
# Epoch 98/200
# 4/4 - 0s - 29ms/step - loss: 0.2388 - val_loss: 0.1753
# Epoch 99/200
# 4/4 - 0s - 25ms/step - loss: 0.2386 - val_loss: 0.1755
# Epoch 100/200
# 4/4 - 0s - 85ms/step - loss: 0.2384 - val_loss: 0.1758
# Epoch 101/200
# 4/4 - 0s - 31ms/step - loss: 0.2382 - val_loss: 0.1760
# Epoch 102/200
# 4/4 - 0s - 26ms/step - loss: 0.2380 - val_loss: 0.1762
# Epoch 103/200
# 4/4 - 0s - 25ms/step - loss: 0.2378 - val_loss: 0.1765
# Epoch 104/200
# 4/4 - 0s - 26ms/step - loss: 0.2376 - val_loss: 0.1767
# Epoch 105/200
# 4/4 - 0s - 25ms/step - loss: 0.2374 - val_loss: 0.1770
# Epoch 106/200
# 4/4 - 0s - 25ms/step - loss: 0.2372 - val_loss: 0.1772
# Epoch 107/200
# 4/4 - 0s - 24ms/step - loss: 0.2370 - val_loss: 0.1775
# Epoch 108/200
# 4/4 - 0s - 26ms/step - loss: 0.2369 - val_loss: 0.1777
# Epoch 109/200
# 4/4 - 0s - 27ms/step - loss: 0.2367 - val_loss: 0.1779
# Epoch 110/200
# 4/4 - 0s - 28ms/step - loss: 0.2365 - val_loss: 0.1782
# Epoch 111/200
# 4/4 - 0s - 26ms/step - loss: 0.2363 - val_loss: 0.1784
# Epoch 112/200
# 4/4 - 0s - 25ms/step - loss: 0.2361 - val_loss: 0.1787
# Epoch 113/200
# 4/4 - 0s - 25ms/step - loss: 0.2359 - val_loss: 0.1789
# Epoch 114/200
# 4/4 - 0s - 27ms/step - loss: 0.2357 - val_loss: 0.1791
# Epoch 115/200
# 4/4 - 0s - 27ms/step - loss: 0.2355 - val_loss: 0.1794
# Epoch 116/200
# 4/4 - 0s - 28ms/step - loss: 0.2353 - val_loss: 0.1796
# Epoch 117/200
# 4/4 - 0s - 27ms/step - loss: 0.2351 - val_loss: 0.1798
# Epoch 118/200
# 4/4 - 0s - 25ms/step - loss: 0.2349 - val_loss: 0.1800
# Epoch 119/200
# 4/4 - 0s - 27ms/step - loss: 0.2348 - val_loss: 0.1803
# Epoch 120/200
# 4/4 - 0s - 25ms/step - loss: 0.2346 - val_loss: 0.1805
# Epoch 121/200
# 4/4 - 0s - 28ms/step - loss: 0.2344 - val_loss: 0.1807
# Epoch 122/200
# 4/4 - 0s - 28ms/step - loss: 0.2342 - val_loss: 0.1809
# Epoch 123/200
# 4/4 - 0s - 27ms/step - loss: 0.2340 - val_loss: 0.1811
# Epoch 124/200
# 4/4 - 0s - 25ms/step - loss: 0.2338 - val_loss: 0.1813
# Epoch 125/200
# 4/4 - 0s - 25ms/step - loss: 0.2336 - val_loss: 0.1816
# Epoch 126/200
# 4/4 - 0s - 25ms/step - loss: 0.2334 - val_loss: 0.1818
# Epoch 127/200
# 4/4 - 0s - 25ms/step - loss: 0.2332 - val_loss: 0.1820
# Epoch 128/200
# 4/4 - 0s - 25ms/step - loss: 0.2330 - val_loss: 0.1822
# Epoch 129/200
# 4/4 - 0s - 27ms/step - loss: 0.2328 - val_loss: 0.1824
# Epoch 130/200
# 4/4 - 0s - 26ms/step - loss: 0.2326 - val_loss: 0.1826
# Epoch 131/200
# 4/4 - 0s - 26ms/step - loss: 0.2324 - val_loss: 0.1827
# Epoch 132/200
# 4/4 - 0s - 32ms/step - loss: 0.2322 - val_loss: 0.1829
# Epoch 133/200
# 4/4 - 0s - 28ms/step - loss: 0.2320 - val_loss: 0.1831
# Epoch 134/200
# 4/4 - 0s - 25ms/step - loss: 0.2318 - val_loss: 0.1833
# Epoch 135/200
# 4/4 - 0s - 24ms/step - loss: 0.2316 - val_loss: 0.1835
# Epoch 136/200
# 4/4 - 0s - 25ms/step - loss: 0.2314 - val_loss: 0.1837
# Epoch 137/200
# 4/4 - 0s - 25ms/step - loss: 0.2312 - val_loss: 0.1838
# Epoch 138/200
# 4/4 - 0s - 25ms/step - loss: 0.2310 - val_loss: 0.1840
# Epoch 139/200
# 4/4 - 0s - 27ms/step - loss: 0.2308 - val_loss: 0.1842
# Epoch 140/200
# 4/4 - 0s - 25ms/step - loss: 0.2305 - val_loss: 0.1844
# Epoch 141/200
# 4/4 - 0s - 25ms/step - loss: 0.2303 - val_loss: 0.1845
# Epoch 142/200
# 4/4 - 0s - 26ms/step - loss: 0.2301 - val_loss: 0.1847
# Epoch 143/200
# 4/4 - 0s - 29ms/step - loss: 0.2299 - val_loss: 0.1848
# Epoch 144/200
# 4/4 - 0s - 31ms/step - loss: 0.2297 - val_loss: 0.1850
# Epoch 145/200
# 4/4 - 0s - 27ms/step - loss: 0.2295 - val_loss: 0.1852
# Epoch 146/200
# 4/4 - 0s - 24ms/step - loss: 0.2293 - val_loss: 0.1853
# Epoch 147/200
# 4/4 - 0s - 25ms/step - loss: 0.2290 - val_loss: 0.1855
# Epoch 148/200
# 4/4 - 0s - 24ms/step - loss: 0.2288 - val_loss: 0.1856
# Epoch 149/200
# 4/4 - 0s - 25ms/step - loss: 0.2286 - val_loss: 0.1858
# Epoch 150/200
# 4/4 - 0s - 24ms/step - loss: 0.2284 - val_loss: 0.1859
# Epoch 151/200
# 4/4 - 0s - 25ms/step - loss: 0.2281 - val_loss: 0.1861
# Epoch 152/200
# 4/4 - 0s - 25ms/step - loss: 0.2279 - val_loss: 0.1862
# Epoch 153/200
# 4/4 - 0s - 25ms/step - loss: 0.2277 - val_loss: 0.1863
# Epoch 154/200
# 4/4 - 0s - 26ms/step - loss: 0.2274 - val_loss: 0.1865
# Epoch 155/200
# 4/4 - 0s - 25ms/step - loss: 0.2272 - val_loss: 0.1866
# Epoch 156/200
# 4/4 - 0s - 25ms/step - loss: 0.2270 - val_loss: 0.1868
# Epoch 157/200
# 4/4 - 0s - 25ms/step - loss: 0.2267 - val_loss: 0.1869
# Epoch 158/200
# 4/4 - 0s - 25ms/step - loss: 0.2265 - val_loss: 0.1870
# Epoch 159/200
# 4/4 - 0s - 25ms/step - loss: 0.2263 - val_loss: 0.1872
# Epoch 160/200
# 4/4 - 0s - 27ms/step - loss: 0.2260 - val_loss: 0.1873
# Epoch 161/200
# 4/4 - 0s - 28ms/step - loss: 0.2258 - val_loss: 0.1874
# Epoch 162/200
# 4/4 - 0s - 30ms/step - loss: 0.2255 - val_loss: 0.1876
# Epoch 163/200
# 4/4 - 0s - 28ms/step - loss: 0.2253 - val_loss: 0.1877
# Epoch 164/200
# 4/4 - 0s - 25ms/step - loss: 0.2250 - val_loss: 0.1878
# Epoch 165/200
# 4/4 - 0s - 25ms/step - loss: 0.2248 - val_loss: 0.1880
# Epoch 166/200
# 4/4 - 0s - 24ms/step - loss: 0.2245 - val_loss: 0.1881
# Epoch 167/200
# 4/4 - 0s - 27ms/step - loss: 0.2242 - val_loss: 0.1882
# Epoch 168/200
# 4/4 - 0s - 28ms/step - loss: 0.2240 - val_loss: 0.1884
# Epoch 169/200
# 4/4 - 0s - 29ms/step - loss: 0.2237 - val_loss: 0.1885
# Epoch 170/200
# 4/4 - 0s - 27ms/step - loss: 0.2235 - val_loss: 0.1886
# Epoch 171/200
# 4/4 - 0s - 26ms/step - loss: 0.2232 - val_loss: 0.1888
# Epoch 172/200
# 4/4 - 0s - 30ms/step - loss: 0.2229 - val_loss: 0.1889
# Epoch 173/200
# 4/4 - 0s - 28ms/step - loss: 0.2226 - val_loss: 0.1890
# Epoch 174/200
# 4/4 - 0s - 31ms/step - loss: 0.2224 - val_loss: 0.1892
# Epoch 175/200
# 4/4 - 0s - 29ms/step - loss: 0.2221 - val_loss: 0.1893
# Epoch 176/200
# 4/4 - 0s - 40ms/step - loss: 0.2218 - val_loss: 0.1895
# Epoch 177/200
# 4/4 - 0s - 25ms/step - loss: 0.2215 - val_loss: 0.1896
# Epoch 178/200
# 4/4 - 0s - 25ms/step - loss: 0.2213 - val_loss: 0.1898
# Epoch 179/200
# 4/4 - 0s - 27ms/step - loss: 0.2210 - val_loss: 0.1899
# Epoch 180/200
# 4/4 - 0s - 27ms/step - loss: 0.2207 - val_loss: 0.1901
# Epoch 181/200
# 4/4 - 0s - 30ms/step - loss: 0.2204 - val_loss: 0.1902
# Epoch 182/200
# 4/4 - 0s - 29ms/step - loss: 0.2201 - val_loss: 0.1904
# Epoch 183/200
# 4/4 - 0s - 36ms/step - loss: 0.2198 - val_loss: 0.1905
# Epoch 184/200
# 4/4 - 0s - 35ms/step - loss: 0.2195 - val_loss: 0.1907
# Epoch 185/200
# 4/4 - 0s - 33ms/step - loss: 0.2192 - val_loss: 0.1909
# Epoch 186/200
# 4/4 - 0s - 27ms/step - loss: 0.2189 - val_loss: 0.1910
# Epoch 187/200
# 4/4 - 0s - 28ms/step - loss: 0.2186 - val_loss: 0.1912
# Epoch 188/200
# 4/4 - 0s - 30ms/step - loss: 0.2183 - val_loss: 0.1914
# Epoch 189/200
# 4/4 - 0s - 27ms/step - loss: 0.2180 - val_loss: 0.1916
# Epoch 190/200
# 4/4 - 0s - 26ms/step - loss: 0.2177 - val_loss: 0.1918
# Epoch 191/200
# 4/4 - 0s - 28ms/step - loss: 0.2173 - val_loss: 0.1920
# Epoch 192/200
# 4/4 - 0s - 26ms/step - loss: 0.2170 - val_loss: 0.1922
# Epoch 193/200
# 4/4 - 0s - 27ms/step - loss: 0.2167 - val_loss: 0.1924
# Epoch 194/200
# 4/4 - 0s - 28ms/step - loss: 0.2164 - val_loss: 0.1926
# Epoch 195/200
# 4/4 - 0s - 27ms/step - loss: 0.2161 - val_loss: 0.1928
# Epoch 196/200
# 4/4 - 0s - 28ms/step - loss: 0.2157 - val_loss: 0.1930
# Epoch 197/200
# 4/4 - 0s - 33ms/step - loss: 0.2154 - val_loss: 0.1933
# Epoch 198/200
# 4/4 - 0s - 37ms/step - loss: 0.2151 - val_loss: 0.1935
# Epoch 199/200
# 4/4 - 0s - 35ms/step - loss: 0.2147 - val_loss: 0.1937
# Epoch 200/200
# 4/4 - 0s - 31ms/step - loss: 0.2144 - val_loss: 0.1940

# %% [markdown]
# ## Opcion 2

# %%
# Creación del modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop, Adam
import tensorflow as tf

# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# El modelo
N_UNITS = 128 # Tamaño del estado oculto (h) y de la celdad de memoria (c) (128)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 5 dias x 45 (features)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))

# Jugar con esta funcion de activacion
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' pues queremos pronosticar (regresión)
# Agregar mas capas y mas numero de neuronas


# Pérdida: se usará el RMSE (root mean squared error) para el entrenamiento
# pues permite tener errores en las mismas unidades
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compilación
optimizador = RMSprop(learning_rate=0.01) # 5e-5
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
)

# Entrenamiento (aproximadamente 1 min usando GPU)
EPOCHS = 100 # Hiperparámetro
BATCH_SIZE = 128 # Hiperparámetro
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)

# %% [markdown]
# ## Opcion 3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# Configurar reproducibilidad
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# Hiperparámetros ajustados para pocos datos
N_UNITS = 8  # Reducir capacidad para evitar overfitting
DROPOUT_RATE = 0.3  # Regularización
LEARNING_RATE = 0.001  # Tasa de aprendizaje más baja
BATCH_SIZE = 4  # Batch pequeño para mejor generalización
EPOCHS = 200
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2])  # (time_steps, n_features)

# Arquitectura
modelo = Sequential([
    # Capa LSTM con regularización
    LSTM(
        N_UNITS, 
        input_shape=INPUT_SHAPE,
        kernel_regularizer=tf.keras.regularizers.l2(1e-4),
        return_sequences=False  # Solo última salida
    ),
    LayerNormalization(),  # Estabiliza entrenamiento
    Dropout(DROPOUT_RATE),
    
    # Capa de salida
    Dense(OUTPUT_LENGTH, activation='linear')
])

# Función de pérdida
def root_mean_squared_error(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

# Optimizador con decaimiento de tasa de aprendizaje
optimizador = Adam(
    learning_rate=LEARNING_RATE, 
    beta_1=0.9, 
    beta_2=0.999, 
    decay=1e-6
)

# Early Stopping para evitar overfitting
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Compilación
modelo.compile(
    optimizer=optimizador,
    loss=root_mean_squared_error
)

# Entrenamiento con aumento de datos en tiempo real
historia = modelo.fit(
    x=x_tr_s,
    y=y_tr_s,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(x_vl_s, y_vl_s),
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# D:\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# D:\anaconda3\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8431 - val_loss: 0.1681
# Epoch 2/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3459 - val_loss: 0.1285
# Epoch 3/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2597 - val_loss: 0.1026
# Epoch 4/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1879 - val_loss: 0.0830
# Epoch 5/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1885 - val_loss: 0.0856
# Epoch 6/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1663 - val_loss: 0.0700
# Epoch 7/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1455 - val_loss: 0.0549
# Epoch 8/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1304 - val_loss: 0.0702
# Epoch 9/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1228 - val_loss: 0.0628
# Epoch 10/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1071 - val_loss: 0.0656
# Epoch 11/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0936 - val_loss: 0.0497
# Epoch 12/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0818 - val_loss: 0.0483
# Epoch 13/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0691 - val_loss: 0.0518
# Epoch 14/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0572 - val_loss: 0.0533
# Epoch 15/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467 - val_loss: 0.0486
# Epoch 16/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0391 - val_loss: 0.0429
# Epoch 17/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0315 - val_loss: 0.0420
# Epoch 18/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0269 - val_loss: 0.0421
# Epoch 19/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - val_loss: 0.0409
# Epoch 20/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0239 - val_loss: 0.0410
# Epoch 21/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0232 - val_loss: 0.0405
# Epoch 22/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0231 - val_loss: 0.0412
# Epoch 23/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228 - val_loss: 0.0404
# Epoch 24/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0227 - val_loss: 0.0405
# Epoch 25/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - val_loss: 0.0400
# Epoch 26/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0405
# Epoch 27/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - val_loss: 0.0402
# Epoch 28/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0215 - val_loss: 0.0397
# Epoch 29/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0211 - val_loss: 0.0398
# Epoch 30/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - val_loss: 0.0398
# Epoch 31/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0209 - val_loss: 0.0397
# Epoch 32/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0207 - val_loss: 0.0394
# Epoch 33/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0207 - val_loss: 0.0396
# Epoch 34/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0205 - val_loss: 0.0392
# Epoch 35/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0205 - val_loss: 0.0392
# Epoch 36/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0206 - val_loss: 0.0394
# Epoch 37/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0203 - val_loss: 0.0391
# Epoch 38/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - val_loss: 0.0389
# Epoch 39/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - val_loss: 0.0389
# Epoch 40/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200 - val_loss: 0.0388
# Epoch 41/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200 - val_loss: 0.0390
# Epoch 42/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0387
# Epoch 43/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195 - val_loss: 0.0388
# Epoch 44/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0388
# Epoch 45/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - val_loss: 0.0386
# Epoch 46/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - val_loss: 0.0384
# Epoch 47/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191 - val_loss: 0.0384
# Epoch 48/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191 - val_loss: 0.0381
# Epoch 49/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - val_loss: 0.0381
# Epoch 50/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0380
# Epoch 51/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0379
# Epoch 52/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0379
# Epoch 53/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - val_loss: 0.0379
# Epoch 54/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0379
# Epoch 55/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0377
# Epoch 56/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0376
# Epoch 57/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0376
# Epoch 58/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - val_loss: 0.0376
# Epoch 59/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - val_loss: 0.0375
# Epoch 60/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - val_loss: 0.0375
# Epoch 61/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0180 - val_loss: 0.0374
# Epoch 62/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - val_loss: 0.0374
# Epoch 63/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - val_loss: 0.0373
# Epoch 64/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - val_loss: 0.0373
# Epoch 65/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - val_loss: 0.0372
# Epoch 66/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0372
# Epoch 67/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0375
# Epoch 68/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0371
# Epoch 69/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0371
# Epoch 70/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0371
# Epoch 71/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0371
# Epoch 72/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177 - val_loss: 0.0371
# Epoch 73/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 74/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177 - val_loss: 0.0371
# Epoch 75/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 76/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 77/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 78/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 79/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 80/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 81/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 82/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 83/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 84/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 85/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 86/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 87/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 88/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 89/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 90/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 91/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0372
# Epoch 92/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 93/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 94/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 95/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 96/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 97/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 98/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 99/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 100/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 101/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 102/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 103/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 104/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 105/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 106/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 107/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 108/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 109/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 110/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 111/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 112/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 113/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 114/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 115/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 116/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 117/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 118/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 119/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 120/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 121/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 122/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 123/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 124/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 125/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 126/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 127/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 128/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0371
# Epoch 129/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 130/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 131/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 132/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 133/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 134/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 135/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 136/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 137/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 138/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 139/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0370
# Epoch 140/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 141/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 142/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 143/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 144/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 145/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0369
# Epoch 146/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 147/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 148/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 149/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 150/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0369
# Epoch 151/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370
# Epoch 152/200
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0370

# %%
 # Graficar curvas de entrenamiento y validación
 # para verificar que no existe overfitting
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Iteración')
plt.ylabel('RMSE')
plt.legend();

# %% [markdown]
# ## Evaluacion del modelo

# %%
# Cálculo de rmses para train, val y test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Imprimir resultados en pantalla
print('Comparativo desempeños:')
print(f'  RMSE train:\t {rmse_tr:.3f}')
print(f'  RMSE val:\t {rmse_vl:.3f}')
print(f'  RMSE test:\t {rmse_ts:.3f}')
# Out:
# Comparativo desempeños:
#   RMSE train:	 0.028
#   RMSE val:	 0.080
#   RMSE test:	 0.003

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Generar las predicciones sobre el set de prueba
y_ts_pred_s = modelo.predict(x_ts_s, verbose=0)

# 2. Verificar las formas de los arrays
print(f"Forma de y_ts_s: {y_ts_s.shape}")
print(f"Forma de y_ts_pred_s: {y_ts_pred_s.shape}")

# 3. Ajustar las formas si es necesario
if len(y_ts_s.shape) == 3:
    y_ts_s = np.squeeze(y_ts_s, axis=-1)
if len(y_ts_pred_s.shape) == 3:
    y_ts_pred_s = np.squeeze(y_ts_pred_s, axis=-1)

# 4. Realizar la transformación inversa de las predicciones
y_ts_original = scaler.inverse_transform(y_ts_s)
y_ts_pred = scaler.inverse_transform(y_ts_pred_s)

# 5. Graficar los datos de prueba y las predicciones
plt.figure(figsize=(12, 6))

# Graficar los datos de prueba (valores reales)
plt.plot(y_ts_original[:, 0], label='Valores Reales (y_ts)', color='blue', alpha=0.7)

# Graficar las predicciones del modelo
plt.plot(y_ts_pred[:, 0], label='Predicciones (y_ts_pred)', color='red', linestyle='--', alpha=0.7)

# Personalizar la gráfica
plt.title('Comparación entre Valores Reales y Predicciones', fontsize=16)
plt.xlabel('Tiempo', fontsize=12)
plt.ylabel('au_recuperacion', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# Mostrar la gráfica
plt.show()
# Out:
# Forma de y_ts_s: (81, 2, 1)
# Forma de y_ts_pred_s: (81, 2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reemplaza "zn_recuperacion" si deseas otra columna
columna = "zn_recuperacion"

# Graficar los últimos 80 valores
df[columna].tail(80).plot(figsize=(12, 5), title=f"Últimos 80 valores de {columna}")
plt.xlabel("Índice")
plt.ylabel(columna)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_ts_s.reshape(-1, 1), y_ts_pred_s.reshape(-1, 1))
print(f'MSE: {mse}')
# Out:
# MSE: 0.002345924769246627

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_ts_s.reshape(-1, 1), y_ts_pred_s.reshape(-1, 1))
print(f'MAE: {mae}')
# Out:
# MAE: 0.03617305871548374

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_ts_s.reshape(-1, 1), y_ts_pred_s.reshape(-1, 1))
print(f'R²: {r2}')
# Out:
# R²: -0.12179575711770574

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(y_ts_s.reshape(-1, 1), y_ts_pred_s.reshape(-1, 1))
print(f'MAPE: {mape}%')
# Out:
# MAPE: 4.348777175612851%
